# %% [markdown]
# # Read & Write Json

# %%
import pandas as pd

# %%
# Read Json file
df = pd.read_json("../data/algo_trading_data.json")
df
# Out:
#         Date  Open  High  Low  Close  Volume
# 0 2023-01-01   100   105   95    102    1000
# 1 2023-01-02   101   106   96    103    1010
# 2 2023-01-03   102   107   97    104    1020
# 3 2023-01-04   103   108   98    105    1030
# 4 2023-01-05   104   109   99    106    1040
# 5 2023-01-06   105   110  100    107    1050
# 6 2023-01-07   106   111  101    108    1060
# 7 2023-01-08   107   112  102    109    1070
# 8 2023-01-09   108   113  103    110    1080
# 9 2023-01-10   109   114  104    111    1090

# %%
data = {
    "Stock_Price": {
        "0": 142.50,
        "1": 145.20,
        "2": 143.75,
        "3": 147.30,
        "4": 146.80,
        "5": 150.25
    },
    "Volume": {
        "0": 3250000,
        "1": 4120000,
        "2": 2870000,
        "3": 5230000,
        "4": 3980000,
        "5": 6150000
    },
    "Moving_Average_50": {
        "0": 140.75,
        "1": 141.20,
        "2": 141.80,
        "3": 142.30,
        "4": 143.10,
        "5": 143.75
    },
    "RSI": {
        "0": 58.2,
        "1": 62.7,
        "2": 56.3,
        "3": 68.9,
        "4": 65.2,
        "5": 72.1
    },
    "Signal": {
        "0": 0,  # 0: Hold
        "1": 1,  # 1: Buy
        "2": 0,  # 0: Hold
        "3": 1,  # 1: Buy
        "4": -1, # -1: Sell
        "5": -1  # -1: Sell
    }
}

# %%
# Read json data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 # df=pd.DataFrame(data)
#       2 # df.to_json("stock_data.json")
# ----> 4 df_read_json = pd.read_json(json.dumps(data), orient='index')
#       5 print("DataFrame using pd.read_json() method:")
#       6 print(df_read_json)
#
# NameError: name 'json' is not defined
