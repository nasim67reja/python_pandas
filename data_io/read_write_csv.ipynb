# %% [markdown]
# # Read & Writes fils

# %% [markdown]
# # CSV

# %%
import pandas as pd

# %%
# Reading csv files
df=pd.read_csv("../data/algo_trading_data.csv")
df
# Out:
#          Date  Open  High  Low  Close  Volume
# 0  2023-01-01   100   105   95    102    1000
# 1  2023-01-02   101   106   96    103    1010
# 2  2023-01-03   102   107   97    104    1020
# 3  2023-01-04   103   108   98    105    1030
# 4  2023-01-05   104   109   99    106    1040
# 5  2023-01-06   105   110  100    107    1050
# 6  2023-01-07   106   111  101    108    1060
# 7  2023-01-08   107   112  102    109    1070
# 8  2023-01-09   108   113  103    110    1080
# 9  2023-01-10   109   114  104    111    1090

# %%
# read csv files with specific columns
df=pd.read_csv("../data/algo_trading_data.csv", usecols=["Date","Open","Close"])
df

# settings columns to be used as index
df=pd.read_csv("../data/algo_trading_data.csv", index_col="Date",nrows=5)
df

# %%
# from external sources
url = "https://media.geeksforgeeks.org/wp-content/uploads/20241121154629307916/people_data.csv"
df = pd.read_csv(url)
df

# %% [markdown]
# ## Saving csv files

# %%
# list of name, degree, score
nme = ["aparna", "pankaj", "sudhir", "Geeku"]
deg = ["MBA", "BCA", "M.Tech", "MBA"]
scr = [90, 40, 80, 98]

# dictionary of lists
dict = {'name': nme, 'degree': deg, 'score': scr}

df = pd.DataFrame(dict)

# saving to csv file
df.to_csv("people_data.csv", index=True, header=True)
# df.to_csv("your_name.csv", sep='\t')
